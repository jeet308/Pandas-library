# %% [markdown]
# Pandas

# %%
import pandas as pd      # import pandas library

# %%
home = pd.read_csv("house_csv.csv") # Loading csv file
# home = pd.read_excel('house_xls.xls')    Loading Excle file

# %%
home.head(10)  #  See the first 10 rows of a DataFrame.
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
home
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home.dtypes  # See all column data types
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
home.columns # See dataframe column names
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
home.info()  # Dataframe info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
home['price'] # Each column data
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
home[['price', 'city']]
# Out:
#              price       city
# 0     3.130000e+05  Shoreline
# 1     2.384000e+06    Seattle
# 2     3.420000e+05       Kent
# 3     4.200000e+05   Bellevue
# 4     5.500000e+05    Redmond
# ...            ...        ...
# 4595  3.081667e+05    Seattle
# 4596  5.343333e+05   Bellevue
# 4597  4.169042e+05     Renton
# 4598  2.034000e+05    Seattle
# 4599  2.206000e+05  Covington
#
# [4600 rows x 2 columns]

# %%
home.iloc[1000]   # Each row data
# Out:
# date             2014-05-20 00:00:00
# price                         384000
# bedrooms                           3
# bathrooms                        2.5
# sqft_living                     1700
# sqft_lot                        4000
# floors                             2
# waterfront                         0
# view                               0
# condition                          3
# sqft_above                      1700
# sqft_basement                      0
# yr_built                        2003
# yr_renovated                       0
# street             35131 SE Ridge St
# city                      Snoqualmie
# statezip                    WA 98065
# country                          USA
# Name: 1000, dtype: object

# %%
home.iloc[800:820]  # Selected rows data
# Out:
#                     date     price  bedrooms  bathrooms  sqft_living  \
# 800  2014-05-16 00:00:00  370000.0       4.0       1.50         1370
# 801  2014-05-16 00:00:00  425000.0       3.0       2.50         2670
# 802  2014-05-16 00:00:00  342000.0       3.0       1.00         1260
# 803  2014-05-16 00:00:00  345000.0       4.0       1.00         1980
# 804  2014-05-16 00:00:00  724800.0       3.0       2.00         2050
# 805  2014-05-16 00:00:00  725000.0       5.0       2.75         2830
# 806  2014-05-16 00:00:00  605000.0       2.0       1.00          910
# 807  2014-05-16 00:00:00  350000.0       4.0       2.50         2440
# 808  2014-05-16 00:00:00  785000.0       3.0       2.00         2180
# 809  2014-05-16 00:00:00  250000.0       3.0       2.00         1900
# 810  2014-05-16 00:00:00  565000.0       3.0       2.25         1520
# 811  2014-05-16 00:00:00  875000.0       3.0       2.00         2220
# 812  2014-05-16 00:00:00  862500.0       4.0       2.75         3280
# ...

# %%
for index,row in home.iterrows():       # for loop using get column data
    print(index,row['city'])
# Out:
# 0 Shoreline
# 1 Seattle
# 2 Kent
# 3 Bellevue
# 4 Redmond
# 5 Seattle
# 6 Redmond
# 7 Maple Valley
# 8 North Bend
# 9 Seattle
# 10 Lake Forest Park
# 11 Seattle
# 12 Sammamish
# 13 Seattle
# 14 Seattle
# 15 Kent
# 16 Bellevue
# 17 Auburn
# 18 Des Moines
# 19 North Bend
# 20 Seattle
# 21 Bellevue
# 22 Seattle
# 23 Bothell
# 24 Seattle
# 25 Federal Way
# 26 Seattle
# 27 Kirkland
# 28 Issaquah
# 29 Seattle
# 30 Kirkland
# 31 Woodinville
# 32 Seattle
# 33 Shoreline
# 34 Auburn
# 35 Federal Way
# 36 Seattle
# 37 Maple Valley
# 38 Normandy Park
# 39 Seattle
# 40 Fall City
# 41 Renton
# 42 Shoreline
# 43 Seattle
# 44 Seattle
# 45 Woodinville
# 46 Issaquah
# 47 Renton
# 48 Seattle
# 49 Redmond
# 50 Issaquah
# 51 Sammamish
# 52 Seattle
# 53 Carnation
# 54 Bothell
# 55 Bellevue
# 56 Auburn
# 57 Snoqualmie
# 58 Seattle
# 59 Seattle
# 60 Snoqualmie
# 61 North Bend
# 62 Renton
# 63 Kent
# 64 Renton
# 65 Seattle
# 66 Issaquah
# 67 Snoqualmie
# 68 Redmond
# 69 Renton
# 70 Auburn
# 71 Seattle
# ...

# %%
home.iloc[10,5]  # Row and Column index using get particular data
# Out:
# 7320

# %%
home.loc[home['city'] == 'Kent' ]
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 2     2014-05-02 00:00:00  342000.000000       3.0       2.00         1930
# 15    2014-05-02 00:00:00  242500.000000       3.0       1.50         1200
# 63    2014-05-02 00:00:00  300000.000000       3.0       2.50         2540
# 176   2014-05-06 00:00:00  284000.000000       4.0       2.50         2000
# 244   2014-05-07 00:00:00  310000.000000       3.0       1.75         2070
# ...                   ...            ...       ...        ...          ...
# 4512  2014-06-19 00:00:00  220083.333333       3.0       1.75         1150
# 4547  2014-06-26 00:00:00  264270.000000       3.0       2.50         1630
# 4560  2014-06-30 00:00:00  132250.000000       4.0       2.25         1830
# 4569  2014-07-02 00:00:00  268971.875000       4.0       2.50         1954
# 4594  2014-07-09 00:00:00  210614.285714       3.0       2.50         1610
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home[['city']].shape # Column shape
# Out:
# (4600, 1)

# %%
home.sort_values('price', ascending=False)     # Sorting values using ascending
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# ...                   ...         ...       ...        ...          ...
# 4472  2014-06-09 00:00:00         0.0       4.0       3.75         4060
# 4567  2014-07-02 00:00:00         0.0       4.0       2.50         4080
# 4354  2014-05-05 00:00:00         0.0       3.0       1.75         1490
# 4454  2014-06-03 00:00:00         0.0       5.0       2.50         2090
# 4382  2014-05-12 00:00:00         0.0       5.0       4.50         4630
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home.sort_values('bedrooms', ascending=False)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 241   2014-05-07 00:00:00   599999.0       9.0       4.50         3830
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 1644  2014-05-30 00:00:00   840000.0       7.0       4.50         4290
# 291   2014-05-07 00:00:00   540000.0       7.0       5.75         3700
# ...                   ...        ...       ...        ...          ...
# 1216  2014-05-22 00:00:00   353000.0       1.0       1.00          550
# 1906  2014-06-04 00:00:00   129000.0       1.0       1.00          650
# 260   2014-05-07 00:00:00   250000.0       1.0       1.00         1100
# 2365  2014-06-12 00:00:00  1095000.0       0.0       0.00         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0       0.00         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home.sort_values(['price' , 'bedrooms'] , ascending=[1,0]) # Multi columns sorting
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4357  2014-05-05 00:00:00         0.0       6.0       2.75         3200
# 4509  2014-06-18 00:00:00         0.0       6.0       3.00         3020
# 4358  2014-05-06 00:00:00         0.0       5.0       3.50         3480
# 4361  2014-05-07 00:00:00         0.0       5.0       1.50         1500
# 4382  2014-05-12 00:00:00         0.0       5.0       4.50         4630
# ...                   ...         ...       ...        ...          ...
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
highpricebedroom = home.loc[(home['bedrooms'] == 7 ) & (home['price'] > 500000.0 )]  # Filter specific rows

# %%
highpricebedroom
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 122   2014-05-05 00:00:00  2280000.0       7.0       8.00        13540
# 252   2014-05-07 00:00:00  3200000.0       7.0       4.50         6210
# 291   2014-05-07 00:00:00   540000.0       7.0       5.75         3700
# 575   2014-05-13 00:00:00   550000.0       7.0       4.00         3440
# 1455  2014-05-28 00:00:00   999000.0       7.0       4.00         3150
# 1479  2014-05-28 00:00:00   565000.0       7.0       4.50         4140
# 1644  2014-05-30 00:00:00   840000.0       7.0       4.50         4290
# 2717  2014-06-17 00:00:00   824000.0       7.0       4.25         3670
# 2917  2014-06-20 00:00:00  1950000.0       7.0       3.50         4640
# 3004  2014-06-20 00:00:00  1240000.0       7.0       5.50         6630
# 4243  2014-07-09 00:00:00   599000.0       7.0       2.50         2580
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
highpricebedroom.reset_index(drop = True)  # Reset index number
# Out:
#                    date      price  bedrooms  bathrooms  sqft_living  \
# 0   2014-05-05 00:00:00  2280000.0       7.0       8.00        13540
# 1   2014-05-07 00:00:00  3200000.0       7.0       4.50         6210
# 2   2014-05-07 00:00:00   540000.0       7.0       5.75         3700
# 3   2014-05-13 00:00:00   550000.0       7.0       4.00         3440
# 4   2014-05-28 00:00:00   999000.0       7.0       4.00         3150
# 5   2014-05-28 00:00:00   565000.0       7.0       4.50         4140
# 6   2014-05-30 00:00:00   840000.0       7.0       4.50         4290
# 7   2014-06-17 00:00:00   824000.0       7.0       4.25         3670
# 8   2014-06-20 00:00:00  1950000.0       7.0       3.50         4640
# 9   2014-06-20 00:00:00  1240000.0       7.0       5.50         6630
# 10  2014-07-09 00:00:00   599000.0       7.0       2.50         2580
#
#     sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
 bedrooms_5 = home[home["bedrooms"] > 5]

# %%
bedrooms_5
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 92    2014-05-05 00:00:00  8.230000e+05       6.0       1.75         2920
# 122   2014-05-05 00:00:00  2.280000e+06       7.0       8.00        13540
# 170   2014-05-06 00:00:00  4.750000e+05       6.0       3.00         3470
# 241   2014-05-07 00:00:00  5.999990e+05       9.0       4.50         3830
# 252   2014-05-07 00:00:00  3.200000e+06       7.0       4.50         6210
# ...                   ...           ...       ...        ...          ...
# 4301  2014-07-10 00:00:00  8.800000e+05       6.0       2.50         2640
# 4341  2014-05-08 00:00:00  3.750000e+05       6.0       2.25         3206
# 4357  2014-05-05 00:00:00  0.000000e+00       6.0       2.75         3200
# 4509  2014-06-18 00:00:00  0.000000e+00       6.0       3.00         3020
# 4572  2014-07-02 00:00:00  1.288333e+06       6.0       4.50         3830
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
bedrooms_5.reset_index(drop = True)
# Out:
#                    date         price  bedrooms  bathrooms  sqft_living  \
# 0   2014-05-05 00:00:00  8.230000e+05       6.0       1.75         2920
# 1   2014-05-05 00:00:00  2.280000e+06       7.0       8.00        13540
# 2   2014-05-06 00:00:00  4.750000e+05       6.0       3.00         3470
# 3   2014-05-07 00:00:00  5.999990e+05       9.0       4.50         3830
# 4   2014-05-07 00:00:00  3.200000e+06       7.0       4.50         6210
# ..                  ...           ...       ...        ...          ...
# 73  2014-07-10 00:00:00  8.800000e+05       6.0       2.50         2640
# 74  2014-05-08 00:00:00  3.750000e+05       6.0       2.25         3206
# 75  2014-05-05 00:00:00  0.000000e+00       6.0       2.75         3200
# 76  2014-06-18 00:00:00  0.000000e+00       6.0       3.00         3020
# 77  2014-07-02 00:00:00  1.288333e+06       6.0       4.50         3830
#
#     sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# ...

# %%
bedrooms_5.shape
# Out:
# (78, 18)

# %%
bedrooms_56 = home[home["bedrooms"].isin([5, 6])]   # Sorting rows

# %%
bedrooms_56
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 14    2014-05-02 00:00:00  1.200000e+06       5.0       2.75         2910
# 28    2014-05-02 00:00:00  6.750000e+05       5.0       2.50         2820
# 54    2014-05-02 00:00:00  4.700000e+05       5.0       2.50         2210
# 57    2014-05-02 00:00:00  7.850000e+05       5.0       3.25         3660
# ...                   ...           ...       ...        ...          ...
# 4540  2014-06-25 00:00:00  3.750000e+05       5.0       3.25         3370
# 4542  2014-06-25 00:00:00  0.000000e+00       5.0       3.50         2640
# 4562  2014-06-30 00:00:00  5.425000e+05       5.0       2.75         2520
# 4572  2014-07-02 00:00:00  1.288333e+06       6.0       4.50         3830
# 4575  2014-07-02 00:00:00  0.000000e+00       5.0       6.25         8020
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
bedrooms_57 = home[(home["bedrooms"] == 5) | (home["bedrooms"] == 7)]

# %%
bedrooms_57
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
# 14    2014-05-02 00:00:00  1200000.0       5.0       2.75         2910
# 28    2014-05-02 00:00:00   675000.0       5.0       2.50         2820
# 54    2014-05-02 00:00:00   470000.0       5.0       2.50         2210
# 57    2014-05-02 00:00:00   785000.0       5.0       3.25         3660
# ...                   ...        ...       ...        ...          ...
# 4529  2014-06-24 00:00:00   542500.0       5.0       2.75         3831
# 4540  2014-06-25 00:00:00   375000.0       5.0       3.25         3370
# 4542  2014-06-25 00:00:00        0.0       5.0       3.50         2640
# 4562  2014-06-30 00:00:00   542500.0       5.0       2.75         2520
# 4575  2014-07-02 00:00:00        0.0       5.0       6.25         8020
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
bedrooms_57.shape
# Out:
# (367, 18)

# %%
view_no = home[home["view"].notna()]

# %%
big_house = home.loc[home["bedrooms"] > 5, "city"]

# %%
big_house
# Out:
# 92            Seattle
# 122           Redmond
# 170           Kenmore
# 241           Seattle
# 252           Seattle
#             ...
# 4301          Seattle
# 4341             Kent
# 4357           Burien
# 4509    Mercer Island
# 4572          Seattle
# Name: city, Length: 78, dtype: object

# %%
big_house.shape
# Out:
# (78,)

# %%
home.iloc[10:25, 2:7]  # Sorting rows and columns
# Out:
#     bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 10       3.0       1.75         1710      7320     1.0
# 11       4.0       2.50         2920      4000     1.5
# 12       3.0       1.75         2330     14892     1.0
# 13       3.0       1.00         1090      6435     1.0
# 14       5.0       2.75         2910      9480     1.5
# 15       3.0       1.50         1200      9720     1.0
# 16       3.0       1.50         1570      6700     1.0
# 17       4.0       3.00         3110      7231     2.0
# 18       3.0       1.75         1370      5858     1.0
# 19       3.0       1.50         1180     10277     1.0
# 20       3.0       1.75         2240     10578     2.0
# 21       4.0       1.00         1450      8800     1.0
# 22       3.0       2.25         1750      1572     2.5
# 23       4.0       2.50         2730     12261     2.0
# 24       4.0       1.75         1600      6380     1.0

# %%
home.head(5)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
home['bedroomsprice'] = home['price']/home['bedrooms'] # Add column

# %%
home.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
home_renamed = home.rename(
     columns={"price": "Home_price"})   # Rename column name

# %%
home_renamed
# Out:
#                      date    Home_price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home_renamed = home_renamed.rename(columns=str.lower)  # Lowercase in conver str

# %%
home_renamed
# Out:
#                      date    home_price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home_renamed["home_price"].mean()   # Column mean values
# Out:
# 551962.9884732141

# %%
 home_renamed[["home_price", "bedrooms"]].median()   # Columns median values
# Out:
# home_price    460943.461539
# bedrooms           3.000000
# dtype: float64

# %%
home_renamed.describe()
# Out:
#          home_price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
home_renamed['bedrooms'].describe()   # Columns describe values
# Out:
# count    4600.000000
# mean        3.400870
# std         0.908848
# min         0.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         9.000000
# Name: bedrooms, dtype: float64

# %%
home_renamed.agg({'home_price': ['min', 'max', 'median', 'skew'],
              'bedrooms': ['min', 'max', 'median', 'mean']})         # Multi-columns mean,median,max,min..etc values
# Out:
#           home_price  bedrooms
# max     2.659000e+07   9.00000
# mean             NaN   3.40087
# median  4.609435e+05   3.00000
# min     0.000000e+00   0.00000
# skew    2.479093e+01       NaN

# %%
home_renamed.head()
# Out:
#                   date  home_price  bedrooms  bathrooms  sqft_living  \
# 0  2014-05-02 00:00:00    313000.0       3.0       1.50         1340
# 1  2014-05-02 00:00:00   2384000.0       5.0       2.50         3650
# 2  2014-05-02 00:00:00    342000.0       3.0       2.00         1930
# 3  2014-05-02 00:00:00    420000.0       3.0       2.25         2000
# 4  2014-05-02 00:00:00    550000.0       4.0       2.50         1940
#
#    sqft_lot  floors  waterfront  view  condition  sqft_above  sqft_basement  \
# 0      7912     1.5           0     0          3        1340              0
# 1      9050     2.0           0     4          5        3370            280
# 2     11947     1.0           0     0          4        1930              0
# 3      8030     1.0           0     0          4        1000           1000
# 4     10500     1.0           0     0          4        1140            800
#
#    yr_built  yr_renovated                    street       city  statezip  \
# ...

# %%
home_renamed[["bedrooms", "bathrooms"]].groupby("bedrooms").mean()
# Out:
#           bathrooms
# bedrooms
# 0.0        0.000000
# 1.0        1.072368
# 2.0        1.401943
# 3.0        1.996924
# 4.0        2.472894
# 5.0        2.859065
# 6.0        2.979508
# 7.0        4.285714
# 8.0        3.125000
# 9.0        4.500000

# %%
home_renamed.groupby("bedrooms")["bathrooms"].mean()
# Out:
# bedrooms
# 0.0    0.000000
# 1.0    1.072368
# 2.0    1.401943
# 3.0    1.996924
# 4.0    2.472894
# 5.0    2.859065
# 6.0    2.979508
# 7.0    4.285714
# 8.0    3.125000
# 9.0    4.500000
# Name: bathrooms, dtype: float64

# %%
home_renamed["bedrooms"].value_counts()   # Column in values count
# Out:
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 0.0       2
# 8.0       2
# 9.0       1
# Name: bedrooms, dtype: int64

# %%
home
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
com_home = pd.read_csv("house_csv.csv", parse_dates=True)

# %%
com_home = com_home[['price','bedrooms','bathrooms']]

# %%
com_home
# Out:
#              price  bedrooms  bathrooms
# 0     3.130000e+05       3.0       1.50
# 1     2.384000e+06       5.0       2.50
# 2     3.420000e+05       3.0       2.00
# 3     4.200000e+05       3.0       2.25
# 4     5.500000e+05       4.0       2.50
# ...            ...       ...        ...
# 4595  3.081667e+05       3.0       1.75
# 4596  5.343333e+05       3.0       2.50
# 4597  4.169042e+05       3.0       2.50
# 4598  2.034000e+05       4.0       2.00
# 4599  2.206000e+05       3.0       2.50
#
# [4600 rows x 3 columns]

# %%
mainhome = pd.concat([home, home_renamed],
                     keys=["home", "rename"])    # Add multi-table

# %%
maihome
# Out:
#                             date      price  bedrooms  bathrooms  sqft_living  \
# home   0     2014-05-02 00:00:00   313000.0       3.0       1.50         1340
#        1     2014-05-02 00:00:00  2384000.0       5.0       2.50         3650
#        2     2014-05-02 00:00:00   342000.0       3.0       2.00         1930
#        3     2014-05-02 00:00:00   420000.0       3.0       2.25         2000
#        4     2014-05-02 00:00:00   550000.0       4.0       2.50         1940
# ...                          ...        ...       ...        ...          ...
# rename 4595  2014-07-09 00:00:00        NaN       3.0       1.75         1510
#        4596  2014-07-09 00:00:00        NaN       3.0       2.50         1460
#        4597  2014-07-09 00:00:00        NaN       3.0       2.50         3010
#        4598  2014-07-10 00:00:00        NaN       4.0       2.00         2090
#        4599  2014-07-10 00:00:00        NaN       3.0       2.50         1490
#
# ...

# %%
home.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
home["street"].str.lower()      # Columns str-values convert in lowercase
# Out:
# 0           18810 densmore ave n
# 1                709 w blaine st
# 2       26206-26214 143rd ave se
# 3                857 170th pl ne
# 4              9105 170th ave ne
#                   ...
# 4595              501 n 143rd st
# 4596            14855 se 10th pl
# 4597            759 ilwaco pl ne
# 4598           5148 s creston st
# 4599           18717 se 258th st
# Name: street, Length: 4600, dtype: object

# %%
home["street"].str.split(",")
# Out:
# 0           [18810 Densmore Ave N]
# 1                [709 W Blaine St]
# 2       [26206-26214 143rd Ave SE]
# 3                [857 170th Pl NE]
# 4              [9105 170th Ave NE]
#                    ...
# 4595              [501 N 143rd St]
# 4596            [14855 SE 10th Pl]
# 4597            [759 Ilwaco Pl NE]
# 4598           [5148 S Creston St]
# 4599           [18717 SE 258th St]
# Name: street, Length: 4600, dtype: object

# %%
home.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
home["city"].str.len()   # Columns values len
# Out:
# 0       9
# 1       7
# 2       4
# 3       8
# 4       7
#        ..
# 4595    7
# 4596    8
# 4597    6
# 4598    7
# 4599    9
# Name: city, Length: 4600, dtype: int64

# %%
home["street"].str.len().idxmax()   # Maximum len in column
# Out:
# 2249

# %%
home.loc[home["street"].str.len().idxmax(), "street"]
# Out:
# '25804-25810 Lake Wilderness Country Club Dr SE'

# %%
home.loc[home['city'].str.contains('Seattle|Redmond', regex = True)]     # Regex using filter data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# 5     2014-05-02 00:00:00  4.900000e+05       2.0       1.00          880
# 6     2014-05-02 00:00:00  3.350000e+05       2.0       2.00         1350
# 9     2014-05-02 00:00:00  6.400000e+05       4.0       2.00         1520
# ...                   ...           ...       ...        ...          ...
# 4582  2014-07-07 00:00:00  4.060625e+05       2.0       1.00         1290
# 4585  2014-07-07 00:00:00  4.868950e+05       3.0       1.00         1890
# 4591  2014-07-08 00:00:00  3.961667e+05       3.0       1.75         1880
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
import re
home.loc[home['city'].str.contains('seattle|redmond',flags = re.I, regex = True)]

# %%
home.loc[home['city'].str.contains('^p[a-z]*',flags=re.I, regex = True)]
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 5     2014-05-02 00:00:00  4.900000e+05       2.0       1.00          880
# 9     2014-05-02 00:00:00  6.400000e+05       4.0       2.00         1520
# 11    2014-05-02 00:00:00  1.400000e+06       4.0       2.50         2920
# 13    2014-05-02 00:00:00  3.650000e+05       3.0       1.00         1090
# ...                   ...           ...       ...        ...          ...
# 4582  2014-07-07 00:00:00  4.060625e+05       2.0       1.00         1290
# 4585  2014-07-07 00:00:00  4.868950e+05       3.0       1.00         1890
# 4591  2014-07-08 00:00:00  3.961667e+05       3.0       1.75         1880
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
home.to_csv('savedemo.txt')   # Save dataframe

# %%
home.loc[(home['city'].str.contains('tle')) & ~(home['bedrooms']<5)]
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 14    2014-05-02 00:00:00  1.200000e+06       5.0       2.75         2910
# 92    2014-05-05 00:00:00  8.230000e+05       6.0       1.75         2920
# 99    2014-05-05 00:00:00  1.395000e+06       5.0       3.50         4010
# 104   2014-05-05 00:00:00  4.350000e+05       5.0       2.00         1840
# ...                   ...           ...       ...        ...          ...
# 4325  2014-06-20 00:00:00  1.234582e+06       5.0       3.25         3240
# 4398  2014-05-19 00:00:00  1.950000e+05       5.0       3.75         5340
# 4448  2014-06-03 00:00:00  0.000000e+00       5.0       2.75         2740
# 4479  2014-06-11 00:00:00  0.000000e+00       5.0       2.00         1910
# 4572  2014-07-02 00:00:00  1.288333e+06       6.0       4.50         3830
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
#for df in pd.read_csv('house_csv.csv',chunksize=5):     # dataframe see in 5 row's group
#    print(df)
